# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parents[1]))

from src.graphs import ErdosRenyiGraph, ScaleFreeGraph, WattsStrogatzGraph, SNAPGraph, MultiLayerGraph
from src.visualization.plots import analyse_graph, analyse_multilayer

# %%
# Las funciones show_full / show_multilayer ahora viven en src.visualization.plots
# como analyse_graph / analyse_multilayer. Nada que definir aquí.
show_full = analyse_graph
show_multilayer = analyse_multilayer

# %% [markdown]
# ## Erdős-Rényi

# %%
# ── Parametros ──────────────────────────────────────────────
NUM_NODES = 500
EDGE_PROB = 0.02
SEED      = 42
# ────────────────────────────────────────────────────────────

g = ErdosRenyiGraph(num_nodes=NUM_NODES, edge_prob=EDGE_PROB, seed=SEED)
show_full(g.graph, f'Erdos-Renyi  G({NUM_NODES}, p={EDGE_PROB})', seed=SEED)
# Out:
# {'n': 500,
#  'm': 4874,
#  'density': 0.01953507014028056,
#  'n_components': 1,
#  'lcc_size': 500,
#  'lcc_fraction': 1.0,
#  'transitivity': 0.01664055553203201,
#  'avg_shortest_path': 2.96,
#  'diameter': 5,
#  'assortativity': -0.006733176758196593,
#  'betweenness_max': 0.01869112027807843,
#  'betweenness_avg': 0.003920588978195721,
#  'pagerank_max': 0.0036543221391789078,
#  'pagerank_avg': 0.0019999999999999996,
#  'n_scc': 1,
#  'reciprocity': 1.0,
#  'in_degree_max': 19,
#  'in_degree_avg': 9.748,
#  'out_degree_max': 19,
#  'out_degree_avg': 9.748,
#  'powerlaw_gamma_in': 1.3426871317366613,
#  'powerlaw_gamma_out': 1.3426871317366613}

# %% [markdown]
# ## Watts-Strogatz (Small World)

# %%
# ── Parametros ──────────────────────────────────────────────
NUM_NODES   = 500
K           = 6
REWIRE_PROB = 0.1
SEED        = 42
# ────────────────────────────────────────────────────────────

g = WattsStrogatzGraph(num_nodes=NUM_NODES, k=K, rewire_prob=REWIRE_PROB, seed=SEED)
show_full(g.graph, f'Watts-Strogatz  n={NUM_NODES}  k={K}  p={REWIRE_PROB}', seed=SEED)
# Out:
# {'n': 500,
#  'm': 3000,
#  'density': 0.012024048096192385,
#  'n_components': 1,
#  'lcc_size': 500,
#  'lcc_fraction': 1.0,
#  'transitivity': 0.45381789556546837,
#  'avg_shortest_path': 5.660040080160321,
#  'diameter': 11,
#  'assortativity': -0.003981415218744102,
#  'betweenness_max': 0.0690000926974889,
#  'betweenness_avg': 0.009334317009020297,
#  'pagerank_max': 0.002838309540106209,
#  'pagerank_avg': 0.0019999999999999996,
#  'n_scc': 1,
#  'reciprocity': 1.0,
#  'in_degree_max': 9,
#  'in_degree_avg': 6.0,
#  'out_degree_max': 9,
#  'out_degree_avg': 6.0,
#  'powerlaw_gamma_in': 1.4035535282605607,
#  'powerlaw_gamma_out': 1.4035535282605607}

# %% [markdown]
# ## Scale-Free (Barabási-Albert extendido)

# %%
# ── Parametros ──────────────────────────────────────────────
NUM_NODES  = 500
ALPHA      = 0.41
BETA       = 0.54
GAMMA      = 0.05
DELTA_IN   = 0.2
DELTA_OUT  = 0.0
SEED       = 42
# ────────────────────────────────────────────────────────────

g = ScaleFreeGraph(
    num_nodes=NUM_NODES, alpha=ALPHA, beta=BETA, gamma=GAMMA,
    delta_in=DELTA_IN, delta_out=DELTA_OUT, seed=SEED,
)
show_full(
    g.graph,
    f'Scale-Free  n={NUM_NODES}  a={ALPHA}  b={BETA}  g={GAMMA}',
    seed=SEED,
)
# Out:
# {'n': 500,
#  'm': 858,
#  'density': 0.003438877755511022,
#  'n_components': 1,
#  'lcc_size': 500,
#  'lcc_fraction': 1.0,
#  'transitivity': 0.13549752999294284,
#  'avg_shortest_path': 2.9585004009623095,
#  'diameter': 7,
#  'assortativity': -0.23406889930684951,
#  'betweenness_max': 0.04724163319946454,
#  'betweenness_avg': 0.00026184738955823295,
#  'pagerank_max': 0.12883108899075355,
#  'pagerank_avg': 0.002000000000000001,
#  'n_scc': 484,
#  'reciprocity': 0.013986013986013986,
#  'in_degree_max': 193,
#  'in_degree_avg': 1.716,
#  'out_degree_max': 22,
#  'out_degree_avg': 1.716,
#  'powerlaw_gamma_in': 1.6201843569982022,
#  'powerlaw_gamma_out': 1.9127857966587132}

# %% [markdown]
# ## SNAP — Red real

# %%
# ── Parametros ──────────────────────────────────────────────
DATASET   = 'ego-Facebook'
CACHE_DIR = '../../data/snap'
DIRECTED  = False
SEED      = 42
# ────────────────────────────────────────────────────────────

g = SNAPGraph(dataset_name=DATASET, cache_dir=CACHE_DIR, directed=DIRECTED, seed=SEED)
tipo = 'dirigido' if DIRECTED else 'no dirigido'
show_full(g.graph, f'SNAP — {DATASET} ({tipo})', seed=SEED)
# Out:
# [cache] ego-Facebook: ya existe en ../../data/snap/raw/ego-Facebook.txt.gz
# [cache] ego-Facebook: ya descomprimido en ../../data/snap/processed/ego-Facebook.txt
# {'n': 4039,
#  'm': 176468,
#  'density': 0.010819963503439287,
#  'n_components': 1,
#  'lcc_size': 4039,
#  'lcc_fraction': 1.0,
#  'transitivity': 0.5191742775433075,
#  'avg_shortest_path': 3.626643552913984,
#  'diameter': 8,
#  'assortativity': 0.0635772291856494,
#  'betweenness_max': 0.48304504473076193,
#  'betweenness_avg': 0.0006711510308511188,
#  'pagerank_max': 0.0076145868447496,
#  'pagerank_avg': 0.0002475860361475613,
#  'n_scc': 1,
#  'reciprocity': 1.0,
#  'in_degree_max': 1045,
#  'in_degree_avg': 43.69101262688784,
#  'out_degree_max': 1045,
#  'out_degree_avg': 43.69101262688784,
#  'powerlaw_gamma_in': 1.2587730752094903,
#  'powerlaw_gamma_out': 1.2587730752094903}

# %% [markdown]
# ## Multilayer — ScaleFree (digital) + Watts-Strogatz (analogica)

# %%
# ── Parametros ──────────────────────────────────────────────
NUM_NODES    = 300
# Capa digital (ScaleFree)
SF_ALPHA     = 0.41
SF_BETA      = 0.54
SF_GAMMA     = 0.05
SF_DELTA_IN  = 0.2
SF_DELTA_OUT = 0.0
# Capa analogica (Watts-Strogatz)
WS_K         = 6
WS_REWIRE    = 0.1
SEED         = 42
# ────────────────────────────────────────────────────────────

digital = ScaleFreeGraph(
    num_nodes=NUM_NODES, alpha=SF_ALPHA, beta=SF_BETA, gamma=SF_GAMMA,
    delta_in=SF_DELTA_IN, delta_out=SF_DELTA_OUT, seed=SEED,
)
analog = WattsStrogatzGraph(num_nodes=NUM_NODES, k=WS_K, rewire_prob=WS_REWIRE, seed=SEED)
ml = MultiLayerGraph(digital_graph=digital, analog_graph=analog, seed=SEED)

show_multilayer(ml.graph, f'Multilayer ScaleFree+WS  n={NUM_NODES}', seed=SEED)
# Out:
# {'analog': {'n': 300,
#   'm': 888,
#   'density': 0.01979933110367893,
#   'n_components': 1,
#   'lcc_size': 300,
#   'lcc_fraction': 1.0,
#   'transitivity': 0.4369127516778524,
#   'avg_shortest_path': 5.028717948717949,
#   'diameter': 10,
#   'assortativity': -0.01878755609645537,
#   'betweenness_max': 0.09097431584337716,
#   'betweenness_avg': 0.013447022534268663,
#   'pagerank_max': 0.0043498094862902134,
#   'pagerank_avg': 0.0033333333333333327,
#   'degree_max': 8,
#   'degree_avg': 5.92,
#   'powerlaw_gamma': 1.4064242169773093,
#   'clustering_avg': 0.44850000000000007,
#   'eigenvector_max': 0.12040322379059294,
#   'eigenvector_avg': 0.054051060767334506},
#  'digital': {'n': 300,
#   'm': 491,
#   'density': 0.005473801560758083,
#   'n_components': 1,
#   'lcc_size': 300,
#   'lcc_fraction': 1.0,
#   'transitivity': 0.11248073959938366,
#   'avg_shortest_path': 2.943047561345047,
#   'diameter': 7,
#   'assortativity': -0.25122156292517345,
#   'betweenness_max': 0.04974272930648769,
#   'betweenness_avg': 0.0004791215815185134,
#   'pagerank_max': 0.11255391106795933,
#   'pagerank_avg': 0.0033333333333333335,
#   'n_scc': 293,
#   'reciprocity': 0.0,
#   'in_degree_max': 111,
#   'in_degree_avg': 1.6366666666666667,
#   'out_degree_max': 14,
#   'out_degree_avg': 1.6366666666666667,
#   'powerlaw_gamma_in': 1.6051870135913533,
#   'powerlaw_gamma_out': 1.9361080350635684},
#  'multilayer': {'active_analog': 300,
#   'active_digital': 300,
#   'active_both': 300,
#   'degree_correlation': -0.37111644473986166,
#   'participation_avg': 0.31759386902922915}}

# %% [markdown]
# ## Multilayer — SNAP (digital) + Watts-Strogatz (analogica)

# %%
# ── Parametros ──────────────────────────────────────────────
DATASET   = 'ego-Facebook'     # ~4 039 nodos; se descarga si no esta en cache
CACHE_DIR = '../../data/snap'
# Capa analogica (Watts-Strogatz) — num_nodes se fija al tamanyo real del dataset
WS_K      = 6
WS_REWIRE = 0.1
SEED      = 42
# ────────────────────────────────────────────────────────────

# Capa digital: SNAP siempre dirigido en multilayer
digital = SNAPGraph(dataset_name=DATASET, cache_dir=CACHE_DIR, directed=True, seed=SEED)
n = len(digital)   # dispara la descarga/parseo; obtiene el nº de nodos real

# Capa analogica con exactamente los mismos n nodos
analog = WattsStrogatzGraph(num_nodes=n, k=WS_K, rewire_prob=WS_REWIRE, seed=SEED)
ml = MultiLayerGraph(digital_graph=digital, analog_graph=analog, seed=SEED)

show_multilayer(ml.graph, f'Multilayer SNAP({DATASET})+WS  n={n}', seed=SEED)
# Out:
# [cache] ego-Facebook: ya existe en ../../data/snap/raw/ego-Facebook.txt.gz
# [cache] ego-Facebook: ya descomprimido en ../../data/snap/processed/ego-Facebook.txt
# {'analog': {'n': 4039,
#   'm': 10996,
#   'density': 0.0013484180552147517,
#   'n_components': 9,
#   'lcc_size': 4030,
#   'lcc_fraction': 0.997771725674672,
#   'transitivity': 0.39147294299218677,
#   'avg_shortest_path': 7.9531926863572435,
#   'diameter': 14,
#   'assortativity': 0.03991746466236343,
#   'betweenness_max': 0.013159721672624681,
#   'betweenness_avg': 0.0017323257411542906,
#   'pagerank_max': 0.0005109794137213782,
#   'pagerank_avg': 0.00024758603614756123,
#   'degree_max': 9,
#   'degree_avg': 5.444912106957168,
#   'powerlaw_gamma': 1.424250266497515,
#   'clustering_avg': 0.3948207359200179,
#   'eigenvector_max': 0.060068764293271806,
#   'eigenvector_avg': 0.01270662028622503},
#  'digital': {'n': 4039,
#   'm': 88234,
#   'density': 0.0054099817517196435,
#   'n_components': 1,
#   'lcc_size': 4039,
#   'lcc_fraction': 1.0,
#   'transitivity': 0.347206471653147,
#   'avg_shortest_path': 5.573838817358131,
#   'diameter': 17,
#   'assortativity': 0.03087056449119572,
#   'betweenness_max': 0.3775485071723903,
#   'betweenness_avg': 0.001006708858145965,
#   'pagerank_max': 0.00987272667973919,
#   'pagerank_avg': 0.0002475860361475613,
#   'n_scc': 442,
#   'reciprocity': 0.0,
#   'in_degree_max': 992,
#   'in_degree_avg': 21.84550631344392,
#   'out_degree_max': 105,
#   'out_degree_avg': 21.84550631344392,
#   'powerlaw_gamma_in': 1.3178674681236893,
#   'powerlaw_gamma_out': 1.3015436870514856},
#  'multilayer': {'active_analog': 4032,
#   'active_digital': 4039,
#   'active_both': 4032,
#   'degree_correlation': -0.3607915640007072,
#   'participation_avg': 0.28377471077234945}}
